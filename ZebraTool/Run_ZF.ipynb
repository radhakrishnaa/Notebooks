% %%
GapeCounter_MU
% Out:
% ans =
%
%      0
%
% ...
% > In GapeCount (line 39)
%   In GapeCounter_MU (line 25)
% ...
% > In GapeCount (line 39)
%   In GapeCounter_MU (line 25)
% GNC stage: 1
% -Pyramid level: 3
% --Iteration: 1   1   (norm of flow increment   13.5934)
% --Iteration: 2   1   (norm of flow increment   9.7091)
% --Iteration: 3   1   (norm of flow increment   9.5537)
% -Pyramid level: 2
% --Iteration: 1   1   (norm of flow increment   28.284)
% --Iteration: 2   1   (norm of flow increment   23.0314)
% --Iteration: 3   1   (norm of flow increment   21.9749)
% -Pyramid level: 1
% --Iteration: 1   1   (norm of flow increment   64.5146)
% --Iteration: 2   1   (norm of flow increment   58.3247)
% --Iteration: 3   1   (norm of flow increment   56.9101)
% GNC stage 1 finished, 0.04 minutes passed
% GNC stage: 2
% -Pyramid level: 2
% --Iteration: 1   1   (norm of flow increment   13.7393)
% --Iteration: 2   1   (norm of flow increment   9.2817)
% --Iteration: 3   1   (norm of flow increment   7.9589)
% ...
