% %%
GapeCounter_MU('600_FF_2_8_L3.tif', './input')
% Out:
% ...
% > In GapeCount (line 39)
%   In GapeCounter_MU (line 23)
% GNC stage: 1
% -Pyramid level: 4
% --Iteration: 1   1   (norm of flow increment   4.3109)
% --Iteration: 2   1   (norm of flow increment   3.0771)
% --Iteration: 3   1   (norm of flow increment   2.8531)
% -Pyramid level: 3
% --Iteration: 1   1   (norm of flow increment   13.9099)
% --Iteration: 2   1   (norm of flow increment   10.442)
% --Iteration: 3   1   (norm of flow increment   10.1306)
% -Pyramid level: 2
% --Iteration: 1   1   (norm of flow increment   36.2589)
% --Iteration: 2   1   (norm of flow increment   30.439)
% --Iteration: 3   1   (norm of flow increment   29.8113)
% -Pyramid level: 1
% --Iteration: 1   1   (norm of flow increment   93.6342)
% --Iteration: 2   1   (norm of flow increment   85.021)
% --Iteration: 3   1   (norm of flow increment   83.6797)
% GNC stage 1 finished, 0.30 minutes passed
% GNC stage: 2
% -Pyramid level: 2
% --Iteration: 1   1   (norm of flow increment   17.9327)
% ...
